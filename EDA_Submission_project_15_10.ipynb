# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayush245101/Paisabazaar-Banking-Fraud-Analysis-Exploratory-Data-Analysis/blob/main/EDA_Submission_project_15_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Member  -** Ayush

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Paisabazaar, a financial services company, aims to improve its credit assessment processes to enhance decision-making and reduce loan defaults. To achieve this, analyzing customer data and classifying their credit scores based on various factors, such as income, credit utilization, and payment behavior, can provide valuable insights that drive better business outcomes.
#
#
#
#
# The dataset contains key features such as annual income, number of bank accounts, credit utilization ratio, outstanding debt, number of delayed payments, and credit history. These features can be utilized to build a predictive model to classify individuals into three credit score categories: “Good,” “Standard,” and “Poor.” The goal is to help Paisabazaar assess the creditworthiness of its customers more accurately and, in turn, offer personalized financial products.
#
#
#
# Through Univariate Analysis, we identified patterns in individual variables. For example, examining age distribution helped us understand the age group most represented among customers. A pie chart of credit scores revealed the proportion of individuals in each creditworthiness category, providing a clear picture of the risk distribution in the customer base. Boxplots of variables like annual income helped highlight variability and the presence of outliers, which are important when considering high-income customers or outliers who may have unique needs.
#
# Bivariate Analysis was employed to explore relationships between variables. A scatter plot between annual income and outstanding debt showed that high-income individuals may have more debt, but this may not necessarily correlate with poor credit scores. A boxplot of credit utilization ratio by credit score category highlighted that customers with higher utilization ratios tend to have poorer credit scores. This finding supports the notion that high credit utilization is a key risk indicator. A line chart comparing monthly in-hand salary with the number of delayed payments provided insight into financial stress, suggesting that lower-income customers are more likely to delay payments.
#
# Multivariate Analysis deepened the exploration by examining how multiple factors interact with each other. A correlation heatmap of numerical features like income, debt, and credit inquiries helped uncover significant relationships between variables that could influence credit scores. Additionally, a pairplot for age, income, and credit score provided a deeper understanding of how these variables are related, especially in highlighting key customer segments.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here:-  https://github.com/Ayush245101

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# Paisabazaar, a leading financial services platform, assists customers in finding and applying for various banking and credit products. A critical component of its service offering is assessing the creditworthiness of individuals, which significantly impacts loan approval decisions and risk management strategies. Financial institutions heavily rely on credit scores to gauge the likelihood that a customer will repay loans or credit balances. However, existing methods for evaluating creditworthiness may not always capture the full picture, leading to potential misclassification of credit risk.
#
# To address this, Paisabazaar seeks to develop a more accurate and data-driven approach to classifying customer credit scores. The primary goal is to improve credit score predictions based on customer demographic and financial data, thereby enhancing loan approval processes, minimizing loan defaults, and enabling the platform to offer more personalized financial products.
#
# The challenge lies in analyzing customer data effectively, identifying key features that influence credit scores, and building a predictive model that classifies individuals into appropriate credit score categories ("Good," "Standard," or "Poor"). In doing so, Paisabazaar can improve decision-making, reduce credit risk, and offer tailored financial advice to customers, ultimately boosting customer satisfaction and profitability.
#
# The task at hand is to explore and analyze customer data, identify the critical factors that affect credit scores, and create a predictive model that enables Paisabazaar to achieve its business objectives.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective in this case study is to enhance Paisabazaar's credit assessment process by developing a predictive model that accurately classifies the credit score of individuals. The model will use various customer features, such as:
#
# *  Income levels,
# *   Credit card usage (Credit Utilization Ratio),
# *   Payment behavior (timeliness, minimum payments),
# * Debt, and
# * Other financial data.
#
# **Key Goals:**
# 1. Improve Risk Management: By better assessing the creditworthiness of individuals, Paisabazaar can reduce loan default risks for partner financial institutions.
# 2. Optimize Loan Approval Process: Automatically classify customers into credit score categories (Good, Standard, Poor) to streamline the approval process.
# 3. Personalized Financial Advice: Provide targeted financial product recommendations (loans, credit cards, etc.) based on a customer’s predicted credit score, improving customer satisfaction

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
from numpy import math
from numpy import loadtxt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams

# !pip install pymysql
import pymysql
from sqlalchemy import create_engine
from sqlalchemy.pool import NullPool

import warnings
warnings.filterwarnings('ignore')
# Out:
# <ipython-input-1-e56664d87ad8>:4: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   from numpy import math
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 2.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df=pd.read_csv('dataset.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head(100)
# Out:
#       ID  Customer_ID  Month             Name   Age          SSN  \
# 0   5634         3392      1    Aaron Maashoh  23.0  821000265.0
# 1   5635         3392      2    Aaron Maashoh  23.0  821000265.0
# 2   5636         3392      3    Aaron Maashoh  23.0  821000265.0
# 3   5637         3392      4    Aaron Maashoh  23.0  821000265.0
# 4   5638         3392      5    Aaron Maashoh  23.0  821000265.0
# ..   ...          ...    ...              ...   ...          ...
# 95  5773        49323      8         Soyoungd  33.0  342902649.0
# 96  5778        15941      1  Harriet McLeodd  35.0  414532918.0
# 97  5779        15941      2  Harriet McLeodd  35.0  414532918.0
# 98  5780        15941      3  Harriet McLeodd  35.0  414532918.0
# 99  5781        15941      4  Harriet McLeodd  35.0  414532918.0
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0      Scientist       19114.12            1824.843333                3.0
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (100000, 28)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.value_counts()
# Out:
# ID      Customer_ID  Month  Name           Age   SSN          Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  Type_of_Loan                                                                                            Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  Payment_Behaviour                 Monthly_Balance  Credit_Score
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
# Visualizing the missing values by using heatmap
sns.heatmap(df.isnull())
plt.title('Missing Value Visualizition')
plt.xlabel('Customer Data')
plt.ylabel('Number of individual')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Based on your Paisabazaar case study and the dataset you are working with, the data includes various features that can be leveraged to predict credit scores, such as:
#
# Income: Helps gauge the customer’s financial stability.
#
# Credit Card Usage: Likely tied to credit utilization, which is important for credit score prediction.
#
# Payment Behavior: This reflects how consistently a customer meets payment deadlines, a key indicator for creditworthiness.
#
#
# The goal of this case study is to use these features to build a model that can accurately classify an individual’s credit score (Good, Standard, or Poor). The dataset provides information like income, outstanding debt, credit history, payment behavior, and loan types, which are essential for building this predictive model.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe to find out statistical data
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df.columns: # using loop to find all columns unique value
    unique_values = df[column].unique()
    print(f"Unique values for {column}: {unique_values}\n")

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df['Payment_of_Min_Amount']=df['Payment_of_Min_Amount'].replace('NM','No') # Replace NM into No according to variable discreption  befor Payment_of_Min_Amount: ['No' 'NM' 'Yes']  after ['No', 'Yes']
df['Payment_of_Min_Amount'].unique()

# %%
# convert float into int
df['Num_Bank_Accounts'].astype('int64')
df['Age'].astype('int64')
df['Num_Credit_Inquiries'].astype('int64')
# round upto two decimal
df['Monthly_Inhand_Salary'].round(2)
df['Total_EMI_per_month'].round(2)
df['Amount_invested_monthly'].round(2)
df['Credit_Utilization_Ratio'].round(2)
df['Monthly_Balance'].round(2)
df['Monthly_Balance'].round(2)
df.head(3)

# %%
# Remove unnesery column like Name and SSN
df.drop('Name',inplace=True,axis=1)
df.drop('SSN',inplace=True,axis=1)

# %%
# find all missing value
missing=df.isnull().sum().sort_values()
missing

# %%
# find duplicte value in data using duplicate function
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# *  The Payment_of_Min_Amount column had some ambiguity ('NM'), which was clarified by replacing it with 'No'.
#
# *  Numeric data was cleaned up by converting floats to integers where appropriate and rounding monetary values for precision.
# *  Personal columns like Name and SSN were dropped as they were not useful for analysis.
#
# *  The dataset was well-prepared, with no missing or duplicate values, indicating a clean and ready-to-use dataset for further analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1   Pie Chart: Credit Score of the person (**U**)

# %%
# Chart - 1 visualization code
plt.pie(df['Credit_Score'].value_counts(),labels=df['Credit_Score'].value_counts().index)
plt.title('Credit Score of the person')
plt.legend(df['Credit_Score'].value_counts().index)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Answer ->  Pie charts are useful for understanding proportions. It shows how different credit scores are distributed as a part of the whole.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Answer -> A majority of customers fall into the "Good" credit score category, with fewer in the "Poor" category.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Answer -> This is a positive insight because it shows the customer base is generally creditworthy.

# %% [markdown]
# #### Chart - 2    Histogram: Distribution of Age (**U**)

# %%
# Chart - 2 visualization code
sns.histplot(df['Age'],bins=10,kde=True,color='b')
plt.title('Age of the person')
plt.xlabel('Age')
plt.ylabel('No of Individual')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Answer -> A histogram is ideal for understanding the age distribution of customers

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Answer -> A skewed distribution (e.g., more customers being younger) could help target age-specific services.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Answer -> Knowing which age groups dominate the customer base allows for targeted marketing and product development.

# %% [markdown]
# #### Chart - 3 Bar Chart for Occupation (**U**)

# %%
# # Chart - 3 visualization code
sns.barplot(y=df['Occupation'].value_counts().index,x=df['Occupation'].value_counts(),palette='Set2')
plt.xlabel('Occupation')
plt.ylabel('Type of Individual')
plt.title('Occupation')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Answer -> To visualize the frequency of different occupations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Answer -> Knowing the occupation with the most loan applicants can help focus marketing efforts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Answer -> Provides clarity on which occupational segments to target for financial products.

# %% [markdown]
# #### Chart - 4 Boxplot: Annual Income (**U**)

# %%
# Chart - 4 visualization code
sns.boxplot(df['Annual_Income'],palette='Set2')
plt.xlabel('Annual_Income')
plt.ylabel('No of Individual')
plt.title('Annual_Income')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Answer ->  A box plot visualizes the spread of the data and helps identify outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Answer ->  There are a few high-income individuals, but most fall within a certain range.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Answer -> Outliers could represent high-net-worth individuals who might require specialized financial services.

# %% [markdown]
# #### Chart - 5  Line Chart: Monthly Balance over Time (Customer ID 3392 as an example) (**B**)

# %%
# Chart - 5 visualization code
cust_data=df[df['Customer_ID']==3392]
plt.plot(cust_data['Month'],cust_data['Monthly_Balance'])
plt.xlabel('Month')
plt.ylabel('Monthly Balance')
plt.title('Monthly Balance over the Month')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Answer ->  Line charts are great for showing trends over time

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Answer -> The balance for this customer shows fluctuations but stays relatively stable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Answer -> Tracking monthly balances helps in understanding cash flow patterns and credit utilization behavior

# %% [markdown]
# #### Chart - 6 Scatter Plot: Annual Income vs. Monthly Inhand Salary (**B**)

# %%
# Chart - 6 visualization code
sns.scatterplot(x=df['Annual_Income'],y=df['Monthly_Inhand_Salary'],palette='Set2')
plt.xlabel('Annual Income')
plt.ylabel('Monthly Inhand Salary')
plt.title('Annual Income vs Monthly Inhand Salary')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Answer -> Scatter plots help to show relationships between two continuous variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Answer -> There is a positive relationship between annual income and monthly salary, as expected.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Answer -> Insights about income can help in offering relevant credit or loan products based on income levels.

# %% [markdown]
# #### Chart - 7 Bar Chart: Payment Behaviour (**U**)

# %%
# Chart - 7 visualization code
sns.barplot(x=df['Payment_Behaviour'].value_counts().index,y=df['Payment_Behaviour'].value_counts(),palette='Set2')
plt.xlabel('Payment Behaviour')
plt.ylabel('No of Individual')
plt.title('Payment Behaviour')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Answer -> A bar chart is ideal for categorical data such as Payment Behaviour.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Answer -> Certain professions like Scientist, Engineer, and Developer are more common.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#   Answer -> Marketing financial products tailored to specific Payment Behaviour (e.g., high-tech workers) could be beneficial.

# %% [markdown]
# #### Chart - 8 Boxplot: Monthly Balance (**U**)

# %%
# Chart - 8 visualization code
sns.boxplot(df['Monthly_Balance'],palette='Set2')
plt.xlabel('Monthly Balance')
plt.ylabel('No of Individual')
plt.title('Monthly Balance')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Answer -> Box plots help visualize the distribution and identify outliers

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Answer -> There are significant outliers in monthly balance, suggesting that some individuals have much higher savings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Answer -> High balances might indicate customers who could be targeted for investment or savings products.

# %% [markdown]
# #### Chart - 9 Pie Chart: Payment of Minimum Amount (**U**)

# %%
# Chart - 9 visualization code
plt.pie(df['Payment_of_Min_Amount'].value_counts(),labels=df['Payment_of_Min_Amount'].value_counts().index)
plt.title('Payment of Min Amount')
plt.legend(df['Payment_of_Min_Amount'].value_counts().index)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Answer ->  Pie charts are great for understanding proportions of binary or categorical data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#   Answer ->  A significant portion of customers do not pay the minimum amount.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Answer -> Customers not paying the minimum could be at risk of default, negatively impacting business.

# %% [markdown]
# #### Chart - 10  Line Chart: Credit Utilization Ratio over the Month of  customer id 3392 as an example (**B**)

# %%
# Chart - 10 visualization code
cust_data=df[df['Customer_ID']==3392]
plt.plot(cust_data['Month'],cust_data['Credit_Utilization_Ratio'],color='r')
plt.xlabel('Month')
plt.ylabel('Credit Utilization Ratio')
plt.title('Credit Utilization Ratio over the Month customer id 3392')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#   Answer -> Line charts effectively show the trend of credit utilization over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Answer -> Credit utilization shows significant fluctuation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#   Answer -> High credit utilization could increase the risk of default, a negative impact on business.

# %% [markdown]
# #### Chart - 11 Histogram: Total EMI per month (**U**)

# %%
# Chart - 11 visualization code
sns.histplot(df['Total_EMI_per_month'],bins=25,kde=True,color='g')
plt.xlabel('EMI Per Month')
plt.ylabel('No of Individual')
plt.title('Total EMI per month')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Answer -> A histogram helps in understanding the distribution of EMI payments.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Answer -> Most customers pay a moderate EMI, with few paying high amounts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Answer -> Moderate EMI payments suggest reasonable debt levels, which is positive for business sustainability.

# %% [markdown]
# #### Chart - 12 Scatter plot: Outstanding Debt vs Credit Utilization Ratio (**B**)

# %%
# Chart - 12 visualization code
sns.scatterplot(x=df['Outstanding_Debt'],y=df['Credit_Utilization_Ratio'],palette='Set2')
plt.xlabel('Outstanding Debt')
plt.ylabel('Credit Utilization Ratio')
plt.title('Outstanding Debt vs Credit Utilization Ratio')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Answer -> Scatter plots show the relationship between two financial metrics.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Answer -> Higher debt correlates with higher credit utilization.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Answer ->  Customers with higher debt may be more prone to financial difficulties, potentially leading to defaults.

# %% [markdown]
# #### Chart - 13 Bar Chart: Number of Bank Account  (**U**)

# %%
# Chart - 13 visualization code
sns.barplot(x=df['Num_Bank_Accounts'].value_counts().index,y=df['Num_Bank_Accounts'].value_counts(),palette='Set2')
plt.xlabel('Num Bank Accounts')
plt.ylabel('No of Individual')
plt.title('Number of Bank Accounts')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Answer -> A bar chart helps to compare the number of individuals with different numbers of bank accounts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Answer -> Most customers have 2-3 bank accounts

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Answer -> Understanding banking behavior helps in offering cross-bank financial products.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap (**M**)

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(12,10))
sns.heatmap((df.select_dtypes(include=['float64', 'int64']).corr()),annot=True, cmap="viridis", fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Answer -> To see correlations between numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Answer -> Strong correlations may reveal key financial behaviors (e.g., high correlation between age and income)

# %% [markdown]
# #### Chart - 15 - Pair Plot (**M**)

# %%
# Pair Plot visualization code
sns.pairplot(df[['Age','Annual_Income','Monthly_Balance','Outstanding_Debt','Credit_Utilization_Ratio','Num_Credit_Inquiries',]],palette='Set2')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Answer ->  To explore relationships between key variables like Age, Income, Balance Debt, Utilizetion, and Inquiries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Answer -> The pair plot helps to visualize any patterns or outliers in the data.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To enhance Paisabazaar’s credit assessment processes and meet their business objectives, I recommend the following key actions based on the data analysis:
#
# 1.  Build a Predictive Credit Score Model:
#   *  Use features such as annual income, outstanding debt, credit utilization ratio, payment behavior, and number of delayed payments to predict a customer’s credit score. Machine learning algorithms like Random Forest, XGBoost, or Logistic Regression can be used to create a robust model that classifies customers into "Good," "Standard," or "Poor" credit score categories.
#  * This model will help automate and improve the accuracy of creditworthiness assessments, reducing the likelihood of loan defaults by identifying high-risk customers early.
# 2. Personalize Financial Product Recommendations:
#
#  * Segment customers based on their credit score and other financial behaviors (such as loan count, credit inquiries, and payment habits). High-credit-score customers could be offered premium loans with lower interest rates, while customers with lower scores might benefit from financial advisory services or smaller loans with tighter controls.
#  * A targeted marketing strategy, using insights on the most frequent occupations and income levels, can help maximize the approval rate and customer satisfaction.
# 3. Risk Management Strategy:
#
#  * Introduce risk-based pricing, where customers with higher credit utilization or delayed payment history are charged slightly higher interest rates to mitigate potential losses. Offering them financial literacy resources or structured repayment plans could improve payment behaviors.
# 3. Improve Credit Education and Counseling:
#
#  * Customers who only pay the minimum or have a high credit utilization ratio can be flagged for proactive credit counseling. Educating customers on how to improve their credit scores (through timely payments, reducing outstanding debts, etc.) can help both the business and the customers in the long term.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, by leveraging data-driven insights and developing a predictive credit score model, Paisabazaar can significantly improve its credit assessment process. This will not only help in mitigating loan defaults but also enable personalized financial offerings to customers, leading to increased customer satisfaction and loyalty. Additionally, focusing on risk management through targeted pricing and financial education will help manage high-risk customers more effectively and promote positive business growth.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
